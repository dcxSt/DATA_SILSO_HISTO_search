# %% [markdown]
# Some stacked area charts of the data, it's purpose is similar to the event-plot but allows us to see more clearely how the tables are constructed from 1860 to 1870. The stacked area charts also allows us to see where there are not many observations being made. Unfortunately the method is not optimally designed, it does the job but you may have to wait a while for it to load... For instance it takes about 1 minuet to load a 40 year time interval which is NOT GOOD :(, you shoulda taken comp 257 lol, if you wanna make inneficient algorithems at least do it in c or java or smt... The fluctuations you see in the drawings are seasonal.

# %%
# import statements        
import mysql.connector
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import math
import datetime as dt
import random

# my files
import db_connection
import db_edit
import db_search
import file_io
import quality_control_tests
from graphs_helper import *
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1860-01-01","1880-01-01"),figsize=(18,12),smoothness=200,
                  display_others=True,observers_list=["WOLF - S - M","WOLF - P - M","Schwabe Drawing",
                                                       "Wolfer","Weber","Schwabe"])
print("time taken to load: ",dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# time taken to load:  0:00:13.945615

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1860-01-01","1900-01-01"),figsize=(18,12),smoothness=200,
                  display_others=True,observers_list=["WOLF - S - M","WOLF - P - M","Schwabe Drawing",
                                                       "Wolfer","Weber","Schwabe"])
print("time taken to load: ",dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# time taken to load:  0:00:59.439650

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1860-01-01","1900-01-01"),figsize=(12,6),smoothness=700,
                  display_others=True,observers_list=["WOLF - S - M","WOLF - P - M","Schwabe Drawing",
                                                       "Wolfer","Weber","Schwabe"],
                 save_as="figures/stacked_wolf_wolfer_schwabe.png",plot_title="1860-1900")
print("time taken to load: ",dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# time taken to load:  0:01:20.232746

# %% [markdown]
# We can see that if you add the blue the orange and the

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1870-01-01","1930-01-01"),figsize=(18,12),smoothness=300,
                  display_others=True,plot_title="Wolfer",observers_list=['Wolfer'])
print("time taken to load: ",dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# time taken to load:  0:02:37.296920

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1870-01-01","1930-01-01"),figsize=(18,12),smoothness=150,
                  display_others=False,plot_title="Wolfer",observers_list=['Wolfer'])
print("time taken to load: ",dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# time taken to load:  0:02:41.491214

# %% [markdown]
# And with Wolf

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1870-01-01","1930-01-01"),figsize=(18,12),smoothness=150,
                  display_others=False,plot_title="Wolfer",observers_list=['Wolfer'])
print("time taken to load: ",dt.datetime.now()-start)

# %% [markdown]
# ### Wolfer investigation

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1800-01-01","1900-01-01"),figsize=(15,12),smoothness=200,display_legend=True)
print(dt.datetime.now()-start)

# %% [markdown]
# ### Long term stacked area charts

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1800-01-01","1900-01-01"),figsize=(18,12),smoothness=1000,display_legend=False)
print(dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# 0:04:43.356754

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1900-01-01","1945-01-01"),figsize=(18,12),smoothness=1000,display_legend=False)
print(dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# 0:01:53.165394

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1600-01-01","1800-01-01"),figsize=(18,12),smoothness=1000,display_legend=False)
print(dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# 0:02:10.425278

# %%
start = dt.datetime.now()
stacked_area_plot(interval=("1600-01-01","1945-01-01"),figsize=(20,15),smoothness=1000,display_legend=False,
                 save_as='stacked_area_chart.png',title='everyone')
print(dt.datetime.now()-start)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# 0:38:57.999253
