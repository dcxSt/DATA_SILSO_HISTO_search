# %% [markdown]
# Shitty notebook that isn't very useful, I think I made this one before the other two, it has some Secchi plots as well as Carrington plots

# %%
# import statements
import numpy as np
import matplotlib.pyplot as plt
import graphs_helper
import time

# %%
# plot Secchi
data_by_obs = graphs_helper.data_by_obs_alias_good()
data_by_obs_seperate_flags = graphs_helper.get_data_by_obs_seperate_flags()
graphs_helper.display_seperate_flags_all(observer="Secchi")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
# plot Carrington
graphs_helper.display_seperate_flags_all(observer="Carrington")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
