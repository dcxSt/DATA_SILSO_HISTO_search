# %% [markdown]
# This is a jupyter notebook to plot the mysterious kremsmunster activity.

# %%
# from the shop
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import spline
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import savgol_filter
import time
import datetime as dt
from datetime import datetime,date
import random

# home-made/
from graphs_helper import *
import scipy.optimize
import pylab
import pickle
import db_edit
import db_connection
import db_transfers
import db_search

# %% [markdown]
# First the originals in the original datbase

# %%
# eventplot
event_plot(interval=None,
          observer_aliases=["Kremsmunster-1","Kremsmuntser-2"],
          the_database="ORIGINAL_DATA_SILSO_HISTO",figsize=(12,6),fontsize=18,
          save_as="figures/kremsmunster_event_og.png")
# Out:
# mysql connection successfully established with ORIGINAL_DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with ORIGINAL_DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...

# %%
# scatter compare observers
display_compare_observers(observers=["Kremsmunster-1","Kremsmuntser-2"],interval=None,
                          the_database="ORIGINAL_DATA_SILSO_HISTO",figsize=(12,12),
                          save_as="figures/kremsmunster_scatter_og.png")
# Out:
# mysql connection successfully established with ORIGINAL_DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with ORIGINAL_DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %% [markdown]
# Then the database as it is now

# %%
# eventplot
event_plot(interval=None,
          observer_aliases=["Kremsmunster-1","Kremsmuntser drawings","Kremsmuntser Theodolitfernrohr drawing",
                           "Kremsmuntser Achromaten drawing","Kremsmuntser Schwarzenbrunner not drawing"],
          the_database="DATA_SILSO_HISTO",figsize=(12,6),fontsize=18,
          save_as="figures/kremsmunster_event_after.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...

# %%
# scatter compare observers
display_compare_observers(observers=["Kremsmunster-1","Kremsmuntser drawings","Kremsmuntser Theodolitfernrohr drawing",
                           "Kremsmuntser Achromaten drawing","Kremsmuntser Schwarzenbrunner not drawing"],
                          interval=None,
                          the_database="DATA_SILSO_HISTO",figsize=(12,12),
                         save_as="figures/kremsmunster_scatter after.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...
