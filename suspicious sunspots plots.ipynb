# %% [markdown]
# This notebook displays sunspot numbers which are unusually big. Here is also where the graphs that show the edits I made to Tacchini's data is stored.

# %%
import numpy as np
import matplotlib.pyplot as plt
from graphs_helper import *
import graphs_helper
import time

# %%
# define a list of suspicious observers with suspicious sunpots
suspicious_observers=["Carrington","Kew","Brunner","Buser",
                     "Sykora","Broger","Guillaume","Heimen",
                     "Quimby","Wolfer","Hrase","Tacchini",
                     "Collins- Haverford","Schwab","Lewitzky",
                     "Weber","Meyer et Billwiller"]#,"Schmitd"]
manualy_cleared_observers=["Weber"]

# %%
# get dictionary from the python file and refine it into 4 
# sections, for non-flagged, flag1 and flag4 and flag5 
data_by_obs = graphs_helper.data_by_obs_alias_good()
data_by_obs_seperate_flags = graphs_helper.get_data_by_obs_seperate_flags()
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
display_seperate_flags("Weber")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
display_seperate_flags("Tacchini",interval=("1876","1880"))#,save_as="tacchini1877_patch.png")
display_seperate_flags("Tacchini",interval=("1880-07","1882-08"))#,save_as="tacchini1881_patch.png")
display_seperate_flags("Tacchini")#,save_as="tacchini_pached.png")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
# suspicious observers plotted, with sunspots
for observer in suspicious_observers:
    if observer not in manualy_cleared_observers:
        display_seperate_flags(observer,yaxis='sunspots')
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
# plot wolf and webber
graphs_helper.display_seperate_flags_all("Tacchini")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
graphs_helper.display_seperate_flags_all("Wolfer")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
# plot wolf and wolfer period
graphs_helper.display_seperate_flags_all("WOLF - S - M")
graphs_helper.display_seperate_flags_all("WOLF - P - M")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...

# %%
# plot groups for all those who are suspicious

# %%
# plot wolf number for all those who are suspicious

# %%
display_seperate_flags("Tacchini",interval=("1876","1880"))#,save_as="tacchini1877_patch.png")
display_seperate_flags("Tacchini",interval=("1880-07-01","1882-08-01"))#,save_as="tacchini1881_patch.png")
display_seperate_flags("Tacchini")#,save_as="tacchini_pached.png")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# No handles with labels found to put in legend.
# data successfully retrieved
# Closing MySQL connection...
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-bdf3e319bbdf> in <module>
#       1 display_seperate_flags("Tacchini",interval=("1876","1880"))#,save_as="tacchini1877_patch.png")
# ----> 2 display_seperate_flags("Tacchini",interval=("1880-07-01","1882-08-01"))#,save_as="tacchini1881_patch.png")
#       3 display_seperate_flags("Tacchini")#,save_as="tacchini_pached.png")
#
# ~/Documents/code/ORB/data_silso_histo/graphs_helper.py in display_seperate_flags(observer, interval, yaxis, save_as)
#     138     if save_as:
#     139         plt.savefig(save_as)
# --> 140     plt.show()
#     141
#     142 # shows figure with 3 subfigures: groups, sunspots, wolf
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1227     def __call__(self):
#    1228         'Return the locations of the ticks'
# -> 1229         self.refresh()
#    1230         return self._locator()
#    1231
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1247     def refresh(self):
#    1248         'Refresh internal information based on current limits.'
# -> 1249         dmin, dmax = self.viewlim_to_dt()
#    1250         self._locator = self.get_locator(dmin, dmax)
#    1251
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#     998                              'often happens if you pass a non-datetime '
#     999                              'value to an axis that has datetime units'
# -> 1000                              .format(vmin))
#    1001         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1002
#
# ValueError: view limit minimum -0.001 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %%
graphs_helper.display_seperate_flags_all("WOLF - P - M")
# Out:
# mysql connection successfully established with GOOD_DATA_SILSO
# data successfully retrieved
# Closing MySQL connection...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-bff7edc20917> in <module>
# ----> 1 graphs_helper.display_seperate_flags_all("WOLF - P - M")
#
# ~/Documents/code/ORB/data_silso_histo/graphs_helper.py in display_seperate_flags_all(observer, interval)
#     204             plt.plot(x[flag_index],ygroups[flag_index],"x",label="flag = "+str(flag_index),color=cmap(flag_index))
#     205     plt.grid()
# --> 206     plt.legend()
#     207
#     208     plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~/anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in __call__(self)
#    1227     def __call__(self):
#    1228         'Return the locations of the ticks'
# -> 1229         self.refresh()
#    1230         return self._locator()
#    1231
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in refresh(self)
#    1247     def refresh(self):
#    1248         'Refresh internal information based on current limits.'
# -> 1249         dmin, dmax = self.viewlim_to_dt()
#    1250         self._locator = self.get_locator(dmin, dmax)
#    1251
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/dates.py in viewlim_to_dt(self)
#     998                              'often happens if you pass a non-datetime '
#     999                              'value to an axis that has datetime units'
# -> 1000                              .format(vmin))
#    1001         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1002
#
# ValueError: view limit minimum -0.001 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
