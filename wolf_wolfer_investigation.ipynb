# %%
# from the shop
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import spline
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import savgol_filter
import time
import datetime as dt
from datetime import datetime,date

# home-made
from graphs_helper import *
import scipy.optimize
import pylab
import pickle
import db_edit
import db_connection
import db_transfers
import db_search

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig"],
                          figsize=(15,40),
                          online_sn=True,smoothness=200)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(the_database="DATA_SILSO_HISTO",observers=["Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser ","Billwiller"],
                          figsize=(15,30),online_sn=True,smoothness=80,
                          interval=("1890-01-01","1893-01-01"))
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...
# no data for Billwiller et Wolfer in groups
# no data for Billwiller in groups
# no data for Billwiller et Wolfer in sunspots
# no data for Billwiller in sunspots
# no data for Billwiller et Wolfer in wolf
# no data for Billwiller in wolf

# %%
display_compare_observers(observers=["Carrington","Carrington derived"],figsize=(17,35),interval=None,
                         online_sn=True,smoothness=100)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig",
                                     "Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser "],
                          figsize=(15,20),interval=None,
                          online_sn=True,smoothness=100)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig",
                                     "Wolf P-M Meyer Weber Schimdt Leppig",
                                     "Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser "],figsize=(15,20),interval=("1875","1895"),
                         online_sn=True,smoothness=50.0)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...
# no data for WOLF - S - M in groups
# no data for Wolf P-M Wielenmann Mayer Schwabe Weber in groups
# no data for Wolf P-M Meyer Schwabe Weber Schimdt in groups
# no data for Wolf P-M Meyer Weber Leppig in groups
# no data for Wolf P-M Meyer Weber Schimdt Leppig in groups
# no data for WOLF - S - M in sunspots
# no data for Wolf P-M Wielenmann Mayer Schwabe Weber in sunspots
# no data for Wolf P-M Meyer Schwabe Weber Schimdt in sunspots
# no data for Wolf P-M Meyer Weber Leppig in sunspots
# no data for Wolf P-M Meyer Weber Schimdt Leppig in sunspots
# no data for WOLF - S - M in wolf
# ...

# %%
display_compare_observers(observers=["Schmidt",
                                     "Schmidt et Würlisch"],
                          figsize=(15,20),online_sn=True,smoothness=100.0)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %%
# list of wolf, wolfer and their associates
wwlist = ["Wolfer","WOLF - S - M","WOLF - P - M","Schwabe",
          "Wolf P-M Wielenmann Mayer Schwabe Weber",
          "Wolf P-M Meyer Schwabe Weber Schimdt",
          "Wolf P-M Meyer Weber Leppig",
          "Billwiller et Wolfer",
          "Wolfer, Mooser ",
          "Meyer et Billwiller",
          "Weber",
          "Leppig",
          "Billwiller",
          "Schmidt",
          "Schmidt et Würlisch"]# had to copy past umlaut from wikpedia

# %%
display_compare_observers(observers=wwlist,figsize=(15,45),online_sn=True,smoothness=100)
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# rubrics sucessfully retrieved
# Closing MySQL connection...

# %%
# plot each of the 40+ observers that observerved in this time period, make a list of them

#cursor,mydb = db_connection.database_connector()
data = db_search.select_all_data()
observers = db_search.select_all_observers()
fk_transition =[]
for i in data:
    if i[1]:
        if i[1]>dt.date(1880,1,1) and i[1]<dt.date(1890,6,1):
            fk_transition.append(i[3])

obs_alias_transition = [i[1] for i in observers if i[0] in fk_transition]
obs_alias_transition.append("WOLF - S - M")
print(obs_alias_transition)


display_compare_observers(obs_alias_transition[:],figsize=(12,26),online_sn=True,smoothness=50,
                          interval=('1884-01-01','1886-01-01'))
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# ['WOLF - P - M', 'Schmidt', 'Weber', 'Leppig', 'Tacchini', 'Schmidt et Würlisch', 'Wurlisch', 'Denza', 'Wolfer', 'Ventosa', 'US Naval', 'Ricco', 'Bruhns', 'Winkler', 'Janesch', 'Tacchini et Millosevich', 'Todd', 'Koukoly', 'Miethe', 'Vogel', 'Schmoll', 'Quimby', 'Ricco et Mascari', 'Wilsing', 'Leavenworth et Gummere', 'Ricco, Zona, Mascari', 'Yendell', 'Catania 1 -  Ricco -  Mascari', 'Frost', 'Ventosa et Escando', 'WOLF - S - M']
#
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
#
# ...
