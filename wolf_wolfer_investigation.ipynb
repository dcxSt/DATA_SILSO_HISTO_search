# %%
# from the shop
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.interpolate import spline
from scipy.ndimage.filters import gaussian_filter1d
import time
import datetime

# home-made
from graphs_helper import *
import scipy.optimize
import pylab
import pickle
import db_edit
import db_connection
import db_transfers

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig",
                                     "Wolf P-M Meyer Weber Schimdt Leppig"],figsize=(15,20),save_as="wolf_comparisons.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(observers=["Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser "],figsize=(15,20),save_as="wolfer_comparisons.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig",
                                     "Wolf P-M Meyer Weber Schimdt Leppig",
                                     "Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser "],figsize=(15,20),interval=None,save_as="wolf_and_wolfer_comparisons.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...

# %%
display_compare_observers(observers=["WOLF - S - M","WOLF - P - M",
                                     "Wolf P-M Wielenmann Mayer Schwabe Weber",
                                     "Wolf P-M Meyer Schwabe Weber Schimdt",
                                     "Wolf P-M Meyer Weber Leppig",
                                     "Wolf P-M Meyer Weber Schimdt Leppig",
                                     "Wolfer",
                                     "Billwiller et Wolfer",
                                     "Wolfer, Mooser "],figsize=(15,20),interval=("1875","1895"),save_as="wolf_and_wolfer_overlap.png")
# Out:
# mysql connection successfully established with DATA_SILSO_HISTO
# data successfully retrieved
# Closing MySQL connection...
#
# mysql connection successfully established with DATA_SILSO_HISTO
# observers sucessfully retrieved
# Closing MySQL connection...
# no data for WOLF - S - M in groups
# no data for Wolf P-M Wielenmann Mayer Schwabe Weber in groups
# no data for Wolf P-M Meyer Schwabe Weber Schimdt in groups
# no data for Wolf P-M Meyer Weber Leppig in groups
# no data for Wolf P-M Meyer Weber Schimdt Leppig in groups
# no data for WOLF - S - M in sunspots
# no data for Wolf P-M Wielenmann Mayer Schwabe Weber in sunspots
# no data for Wolf P-M Meyer Schwabe Weber Schimdt in sunspots
# no data for Wolf P-M Meyer Weber Leppig in sunspots
# no data for Wolf P-M Meyer Weber Schimdt Leppig in sunspots
# no data for WOLF - S - M in wolf
# no data for Wolf P-M Wielenmann Mayer Schwabe Weber in wolf
# no data for Wolf P-M Meyer Schwabe Weber Schimdt in wolf
# ...

# %%
datetime.date(1870,8,1)+ datetime.date(1870,8,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a752c5edba5d> in <module>
# ----> 1 datetime.date(1870,8,1)+ datetime.date(1870,8,2)
#
# TypeError: unsupported operand type(s) for +: 'datetime.date' and 'datetime.date'
